# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\HP\\Downloads\\myexcel - myexcel.csv.csv") 
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head(10)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# 5   Amir Johnson  Boston Celtics      90       PF   29  06-Sep     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21  06-Aug     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25     7-0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22  06-Feb     190
# 9   Marcus Smart  Boston Celtics      36       PG   22  06-Apr     220
#
#              College      Salary  height
# 0              Texas   7730337.0     167
# 1          Marquette   6796117.0     162
# 2  Boston University         NaN     150
# ...

# %%
df.tail(10)
# Out:
#                Name       Team  Number Position  Age  Height  Weight  \
# 448  Gordon Hayward  Utah Jazz      20       SF   26  06-Aug     226
# 449     Rodney Hood  Utah Jazz       5       SG   23  06-Aug     206
# 450      Joe Ingles  Utah Jazz       2       SF   28  06-Aug     226
# 451   Chris Johnson  Utah Jazz      23       SF   26  06-Jun     206
# 452      Trey Lyles  Utah Jazz      41       PF   20  06-Oct     234
# 453    Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203
# 454       Raul Neto  Utah Jazz      25       PG   24  06-Jan     179
# 455    Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256
# 456     Jeff Withey  Utah Jazz      24        C   26     7-0     231
# 457        Priyanka  Utah Jazz      34        C   25  07-Mar     231
#
#       College      Salary  height
# 448    Butler  15409570.0     157
# 449      Duke   1348440.0     160
# 450       NaN   2050000.0     179
# 451    Dayton    981348.0     179
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
#  9   height    458 non-null    int32
# dtypes: float64(1), int32(1), int64(3), object(5)
# memory usage: 34.1+ KB

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary      height
# count  458.000000  458.000000  458.000000  4.470000e+02  458.000000
# mean    17.713974   26.934498  221.543668  4.833970e+06  164.303493
# std     15.966837    4.400128   26.343200  5.226620e+06    8.851660
# min      0.000000   19.000000  161.000000  3.088800e+04  150.000000
# 25%      5.000000   24.000000  200.000000  1.025210e+06  156.000000
# 50%     13.000000   26.000000  220.000000  2.836186e+06  164.000000
# 75%     25.000000   30.000000  240.000000  6.500000e+06  172.000000
# max     99.000000   40.000000  307.000000  2.500000e+07  179.000000

# %%
df.shape
# Out:
# (458, 10)

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary', 'height'],
#       dtype='object')

# %%
# Replace incorrect height data with random numbers between 150 and 180
df['Height'] = np.random.randint(150, 180, size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     150     235
# 2     John Holland  Boston Celtics      30       SG   27     166     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     176     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     156     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     167     203
# 454      Raul Neto       Utah Jazz      25       PG   24     169     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     172     256
# 456    Jeff Withey       Utah Jazz      24        C   26     176     231
# 457       Priyanka       Utah Jazz      34        C   25     170     231
#
#                College     Salary  height
# 0                Texas  7730337.0     167
# ...

# %%
#Q 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
team_counts = df['Team'].value_counts()
team_percentages = team_counts / len(df) * 100
team_counts,team_percentages
# Out:
# (Team
#  New Orleans Pelicans      19
#  Memphis Grizzlies         18
#  Utah Jazz                 16
#  New York Knicks           16
#  Milwaukee Bucks           16
#  Brooklyn Nets             15
#  Portland Trail Blazers    15
#  Oklahoma City Thunder     15
#  Denver Nuggets            15
#  Washington Wizards        15
#  Miami Heat                15
#  Charlotte Hornets         15
#  Atlanta Hawks             15
#  San Antonio Spurs         15
#  Houston Rockets           15
#  Boston Celtics            15
#  Indiana Pacers            15
#  Detroit Pistons           15
#  Cleveland Cavaliers       15
#  Chicago Bulls             15
#  Sacramento Kings          15
#  Phoenix Suns              15
#  Los Angeles Lakers        15
#  Los Angeles Clippers      15
#  Golden State Warriors     15
#  Toronto Raptors           15
#  Philadelphia 76ers        15
#  Dallas Mavericks          15
#  Orlando Magic             14
#  Minnesota Timberwolves    14
#  Name: count, dtype: int64,
# ...

# %%
#Q2.Segregate the employees w.r.t different positions.

# %%
position_counts = df['Position'].value_counts()
position_counts
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plt.bar(position_counts.index,position_counts.values)
plt.xlabel('Position')
plt.ylabel('Number of employees')
plt.show()

# %%
#Q3.Find from which age group most of the employees belong to.

# %%
ag=df["Age"].value_counts().sort_values()
ag
# Out:
# Age
# 19     2
# 39     2
# 40     3
# 38     4
# 37     4
# 35     9
# 36    10
# 34    10
# 32    13
# 33    14
# 21    19
# 20    19
# 31    22
# 22    26
# 29    28
# 30    31
# 28    31
# 26    36
# 23    41
# 27    41
# 25    46
# 24    47
# Name: count, dtype: int64

# %%
age_groups = pd.cut(df['Age'], bins=[20, 25, 30, 35, 40, 45, 50, 55, 60], labels=['20-25', '26-30', '31-35', '36-40', '41-45', '46-50', '51-55', '55+'])
age_group_counts = age_groups.value_counts()
age_group_counts
# Out:
# Age
# 20-25    179
# 26-30    167
# 31-35     68
# 36-40     23
# 41-45      0
# 46-50      0
# 51-55      0
# 55+        0
# Name: count, dtype: int64

# %%
plt.bar(age_group_counts.index,age_group_counts.values)
plt.xlabel('Age group')
plt.ylabel('Number of employees')
plt.show()

# %%
age_groups = age_group_counts.idxmax()
number=age_group_counts.max()
print("Most of the employees belongs to the age group",age_groups,"with total number of employees",number)
# Out:
# Most of the employees belongs to the age group 20-25 with total number of employees 179

# %%
#Q4.Find out under which team and position, spending in terms of salary is high.

# %%
salary_spending = df.groupby(['Team', 'Position'])['Salary'].sum()
salary_spending
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %%
high_salary = salary_spending.idxmax()
print('Team and position under which salary is high is', high_salary)
# Out:
# Team and position under which salary is high is ('Los Angeles Lakers', 'SF')

# %%
#Q5.Find if there is any correlation between age and salary , represent it visually.

# %%
correlation = df['Age'].corr(df['Salary'])
correlation
# Out:
# 0.2140094122657097

# %%
sns.scatterplot(x='Age',y='Salary',data=df)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Corelation between Age and Salary')
plt.show()
